# %% [markdown]
# Link to Haberman Cancer Survival dataset from Kaggle - (https://www.kaggle.com/gilsousa/habermans-survival-data-set)

# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
# we can read the data directly from raw github link
# we are also defining the name of the columns.
#make sure that your csv file and ipynb notebook are in the same folder. If they are in different folder then you have to define the complete path
df=pd.read_csv('haberman.csv',names=["age","operation_year","axil_nodes","survival_status"])
df
# Out:
#      age  operation_year  axil_nodes  survival_status
# 0     30              64           1                1
# 1     30              62           3                1
# 2     30              65           0                1
# 3     31              59           2                1
# 4     31              65           4                1
# ..   ...             ...         ...              ...
# 301   75              62           1                1
# 302   76              67           0                1
# 303   77              65           3                1
# 304   78              65           1                2
# 305   83              58           2                2
#
# [306 rows x 4 columns]

# %%
df.describe()
# Out:
#               age  operation_year  axil_nodes  survival_status
# count  306.000000      306.000000  306.000000       306.000000
# mean    52.457516       62.852941    4.026144         1.264706
# std     10.803452        3.249405    7.189654         0.441899
# min     30.000000       58.000000    0.000000         1.000000
# 25%     44.000000       60.000000    0.000000         1.000000
# 50%     52.000000       63.000000    1.000000         1.000000
# 75%     60.750000       65.750000    4.000000         2.000000
# max     83.000000       69.000000   52.000000         2.000000

# %% [markdown]
# <h4> Number of Points : 1224 <br>
#
# Number of Attributes : 4 (including class attribue) <br>
#
# Number of Features : 3 (age, operation_Year, axil_nodes) <br>
#
# Number of Classes : 2 <br>
#
# Data Points per class : 1-225, 2-81 </h4>

# %% [markdown]
# ### Objective of the problem.

# %% [markdown]
# <p>The dataset contains cases from a study that was conducted between
# 1958 and 1970 at the <br>University of Chicago's Billings Hospital on
# the survival of patients who had undergone surgery for breast
# cancer.
#
# Objective of the problem is to find whether a new pateint who has undergone surgery for breast cancer <br>
# will survive 5 years or longer<br>
# or<br>
# die within 5 years after the surgery.
#
# It is basically a supervised bi-classification problem hence we have two labels in our taget variable (Survival status) i.e., <br>
# 1 = the patient survived 5 years or longer <br>
# 2 = the patient died within 5 year
#
# For the purpose of classifiaction we make use of three features namely :<br>
# age	(Age of patient at time of operation (numerical))<br>
# operation_Year	(Patients year of operation (year - 1900, numerical))<br>
# axil_nodes	(Number of positive axillary nodes detected (numerical)) <p>

# %% [markdown]
# ### Univariate analysis - Plotting PDF, CDF, Boxplot, Voilin plots

# %% [markdown]
# ### (a) Histograms

# %%
a=[]
for i in range(0,101,5):
    a.append(i)

sns.FacetGrid(df, hue="survival_status", size=10) \
   .map(sns.distplot, "age") \
   .add_legend()\
   .set(xticks=a);
plt.title('Histogram of Age')
plt.show();
# Out:
# C:\Users\sowda\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\sowda\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sowda\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(df, hue="survival_status", size=10) \
   .map(sns.distplot, "axil_nodes") \
   .add_legend()\
    .set(xlim=[-10,60],xticks=a);
plt.title('Histogram of Axil Nodes')
plt.show();
# Out:
# C:\Users\sowda\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\sowda\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sowda\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
b=[]
for i in range(55,75):
    b.append(i)
sns.FacetGrid(df, hue="survival_status", size=10) \
   .map(sns.distplot, "operation_year") \
   .add_legend()\
    .set(xlim=[50,75],xticks=b)
plt.title('Histogram of Operation year')
plt.show();
# Out:
# C:\Users\sowda\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\sowda\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sowda\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Observations :
#
# <b>
#
# 1.X-Axis of the plots describe the value range of feature while Y-axis denotes the density i.e., counts.
#
# 2.When plotted against age, we can see that majority of people whose age range is [51-56] has survival rate as 1 while the age group of [40-46] has survival rate 2.
#
# 3.When plotted against no.of postitive axil nodes, we can see that majority of people whose axil_nodes count is [0-2] has survival rate as 1 while if axil_nodes count is greater than 2 has survival rate 2.
#
# 4.When plotted against operation_year, we can see that majority of people who has undergone surgery between the years 1960-62 has survival rate as 1 while the age group of 1963-66 has survival rate 2.</b>

# %% [markdown]
# ### (b) CDF AND PDF

# %%
import numpy as np
ss_1 = df.loc[df["survival_status"] == 1];
ss_2 = df.loc[df["survival_status"] == 2];

counts, bin_edges = np.histogram(ss_1['age'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)
plt.title('PDF and CDF of feature - Age')
plt.xlabel("age")
plt.ylabel("Probability of RV X<=x for CDF, Probability of RV X<=x for PDF ")


legend_drawn_flag = True
plt.legend(["PDF Plot", "CDF Plot"], loc=0, frameon=legend_drawn_flag)




plt.show();
# Out:
# [0.05333333 0.10666667 0.12444444 0.09333333 0.16444444 0.16444444
#  0.09333333 0.11111111 0.06222222 0.02666667]
# [30.  34.7 39.4 44.1 48.8 53.5 58.2 62.9 67.6 72.3 77. ]

# %%
counts, bin_edges = np.histogram(ss_1['axil_nodes'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)


plt.title('PDF and CDF of feature axil_nodes')
plt.xlabel("axil_nodes count")
plt.ylabel("Probability of RV X<=x for CDF, Probability of RV X<=x for PDF ")

location = 0 
legend_drawn_flag = True
plt.legend(["PDF Plot", "CDF Plot"], loc=0, frameon=legend_drawn_flag)

plt.show();
# Out:
# [0.83555556 0.08       0.02222222 0.02666667 0.01777778 0.00444444
#  0.00888889 0.         0.         0.00444444]
# [ 0.   4.6  9.2 13.8 18.4 23.  27.6 32.2 36.8 41.4 46. ]

# %%
counts, bin_edges = np.histogram(ss_1['operation_year'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)


plt.title('PDF and CDF of feature - Operation_year')
plt.xlabel("operation_year")
plt.ylabel("Probability of RV X<=x for CDF, Probability of RV X<=x for PDF ")

location = 0 
legend_drawn_flag = True
plt.legend(["PDF Plot", "CDF Plot"], loc=0, frameon=legend_drawn_flag)


plt.show();
# Out:
# [0.18666667 0.10666667 0.10222222 0.07111111 0.09777778 0.10222222
#  0.06666667 0.09777778 0.09333333 0.07555556]
# [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]

# %% [markdown]
# ### Observations :
#
# <b>
#
# 1.X-Axis of the plots describe the value range of feature while Y-axis denotes the probabilities.
#
# 2.All the plots are drawn by taking survival status as 1 into consideration.
#
# 3.PDF represent how many points exists in a range wihle CDF rrepresents percentage of points that are less than of equal to a certain value.
#
# 4.When plotted against age, 16% of people are aged between 53.5 and 58.2
#
# 5.When plotted against no.of postitive axil nodes 80%, of axil nodes count is [0-3].
#
# 6.When plotted against operation_year, 20% of people's operation year is 1958.

# %% [markdown]
# ### (c) Boxplots

# %%
sns.boxplot(x='survival_status',y='age', data=df)
plt.show()

# %%
sns.boxplot(x='survival_status',y='axil_nodes', data=df)
plt.show()

# %%
sns.boxplot(x='survival_status',y='operation_year', data=df)
plt.show()

# %% [markdown]
# ### Observations :
#
# <b>
#
# 1.X-Axis of the plots describe the target classes and  Y-axis denotes the value range of features
#
# 2.A boxplot is a standardized way of displaying the distribution of data based on a five number summary (minimum, first quartile (Q1), median, third quartile (Q3), maximum). It can tell you about your outliers and what their values are.
#
# 3.When plotted against age distribuation of data there are no ouliers and quartile range is {42,60} for target class "1" and quartile range is {45,60} for target class "2".
#
# 4.When plotted against no.of postitive outliers have been observed and min. value coincides with quartile Q1 and quartile range is {1,3} while for target class "1" while quartile range for target class "2" is {2,10}.
#
# 5.When plotted against operation_year distribuation of data there are no ouliers and quartile range is {60,66} for target class "1" and quartile range is {55,65} for target class "2".

# %% [markdown]
# ### (d) Violin Plots

# %%
sns.violinplot(x='survival_status',y='age', data=df)
plt.show()

# %%
sns.violinplot(x='survival_status',y='axil_nodes', data=df)
plt.show()

# %%
sns.violinplot(x='survival_status',y='operation_year', data=df)
plt.show()

# %% [markdown]
# ### Observations :
#
# <b>
#
# 1.X-Axis of the plots describe the target classes and  Y-axis denotes the value range of features
#
# 2.A violin plot is a hybrid of a box plot and a kernel density plot, which shows peaks in the data. Unlike a box plot that can only show summary statistics, violin plots depict summary statistics and the density of each variable.

# %% [markdown]
# ### Performing Bivariate analysis - Plot 2D Scatter plots and Pair plots
# - Plot the required Scatter plots and Pair plots of different features to see which combination of features are useful for clasification task
# - Make sure that you add titles, legends and labels for each and every plots.
# - Suppress the warnings you get in python, in that way it makes your notebook more presentable.
# - Do write observations/inference for each  plot.

# %% [markdown]
# ### (a) 2D Scatter Plots

# %%
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="survival_status", size=4) \
   .map(plt.scatter, "age", "operation_year") \
   .add_legend();
plt.title('2-D Scatter plot with color-coding for each flower type/class')
plt.show();
# Out:
# C:\Users\sowda\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="survival_status", size=4) \
   .map(plt.scatter, "age", "axil_nodes") \
   .add_legend();
plt.title('2-D Scatter plot with color-coding for each flower type/class')
plt.show();
# Out:
# C:\Users\sowda\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="survival_status", size=4) \
   .map(plt.scatter, "operation_year", "axil_nodes") \
   .add_legend();
plt.title('2-D Scatter plot with color-coding for each flower type/class')
plt.show();
# Out:
# C:\Users\sowda\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Observations
#
# <b>
#
# 1.2D scatter plot is a diagram where each value in the data set is represented by a dot.
#
#
# 2.When plotted by considering two features for a single plot, there is no proper distinction of data points, they all are mixed up making it difficult to find any observations.

# %% [markdown]
# ### (b) Pair Plots

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(df, hue="survival_status", size=3);
plt.title('Pair plots')
plt.show()
# Out:
# C:\Users\sowda\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Observations
#
# <b>
#
# 1.Pair Plots helps us to visualize the relationship among all features in a single instance, the plots in diagonal axis can be neglected as both X and Y axies are plotted against same feature.
#
#
# 2.There is no proper distinction among data points but when plotted age against axil nodes, we can see that irrespective of age if axil nodes count is less than 3 there are many survival chances i.e., survival status is 1.

# %% [markdown]
# # Overall Conclusions

# %% [markdown]
# <b>
#
# 1.As we can see, there is a great range overlap of our target classes when we plotted different univariate graphs based on Age and Opeartion Year, while in the case Axil nodes the survival status is '1' if the count of postive auxiliary nodes is in between range of 0-3 while survival status is '2' if the count of postive auxiliary nodes is  more than 3.
#
#
# 2.Though there is an overlap of both classes in the range 0-3, most probable points shows that survival status is '1'. Out of three featues Axil nodes is much prominet feauture to classify the labels if single varibale is taken into consideration.
#
# 3.When observed in 2D scatter plots there is a great range of overlap among target label points and it's very hard to classify with bivariate analysis, but when pair plots is drawn and compared the plots of different scenairos, there is slight variation of target label points when age and axil nodes is considered.
#
# 4.In conclusion, if Number of positive axillary nodes detected is in range of 0-3, we can assure that the survival status is 1 and if it is out of range then survival status will be 2.|
